# %% [markdown]
# # SRISHTI PANDEY - COVID 19 DATA ANALYSIS PROJECT

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
corona_dataset_csv = pd.read_csv("covid19_Confirmed_dataset.csv")
corona_dataset_csv.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  4/21/20  4/22/20  4/23/20  4/24/20  \
# 0        0        0        0  ...     1092     1176     1279     1351
# 1        0        0        0  ...      609      634      663      678
# 2        0        0        0  ...     2811     2910     3007     3127
# 3        0        0        0  ...      717      723      723      731
# 4        0        0        0  ...       24       25       25       25
#
#    4/25/20  4/26/20  4/27/20  4/28/20  4/29/20  4/30/20
# ...

# %%
corona_dataset_csv.shape
# Out:
# (266, 104)

# %%
corona_dataset_csv.drop(["Lat" ,"Long"], axis = 1,inplace = True )

# %%
corona_dataset_csv.head()
# Out:
#   Province/State Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  \
# 0            NaN    Afghanistan        0        0        0        0        0
# 1            NaN        Albania        0        0        0        0        0
# 2            NaN        Algeria        0        0        0        0        0
# 3            NaN        Andorra        0        0        0        0        0
# 4            NaN         Angola        0        0        0        0        0
#
#    1/27/20  1/28/20  1/29/20  ...  4/21/20  4/22/20  4/23/20  4/24/20  \
# 0        0        0        0  ...     1092     1176     1279     1351
# 1        0        0        0  ...      609      634      663      678
# 2        0        0        0  ...     2811     2910     3007     3127
# 3        0        0        0  ...      717      723      723      731
# 4        0        0        0  ...       24       25       25       25
#
#    4/25/20  4/26/20  4/27/20  4/28/20  4/29/20  4/30/20
# ...

# %% [markdown]
# #Aggregating State Col with Country Col.

# %%
corona_dataset_aggregated = corona_dataset_csv.groupby("Country/Region").sum()

# %%
corona_dataset_aggregated.head(10)
# Out:
#                      1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# Country/Region
# Afghanistan                0        0        0        0        0        0
# Albania                    0        0        0        0        0        0
# Algeria                    0        0        0        0        0        0
# Andorra                    0        0        0        0        0        0
# Angola                     0        0        0        0        0        0
# Antigua and Barbuda        0        0        0        0        0        0
# Argentina                  0        0        0        0        0        0
# Armenia                    0        0        0        0        0        0
# Australia                  0        0        0        0        4        5
# Austria                    0        0        0        0        0        0
#
#                      1/28/20  1/29/20  1/30/20  1/31/20  ...  4/21/20  \
# Country/Region                                           ...
# ...

# %%
corona_dataset_aggregated.shape
# Out:
# (187, 100)

# %% [markdown]
# #Visualizing data with country name

# %%
corona_dataset_aggregated.loc["China"].plot()
corona_dataset_aggregated.loc["India"].plot()
corona_dataset_aggregated.loc["Italy"].plot()
plt.legend()

# %%
corona_dataset_aggregated.loc["China"][:3].plot()
corona_dataset_aggregated.loc["India"]["4/21/20":"4/25/20"].plot()
plt.legend()

# %% [markdown]
# #plotting maximum hike in cases

# %%
corona_dataset_aggregated.loc["China"].diff().plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# #Calculating maximum cases discovered in single day

# %%
corona_dataset_aggregated.loc["China"].diff().max()
# Out:
# 15136.0

# %%
corona_dataset_aggregated.loc["Italy"].diff().max()
# Out:
# 6557.0

# %% [markdown]
# #Calculating maximum Covid cases for all countries

# %%
countries = list(corona_dataset_aggregated.index)
max_infection_rates = []
for c in countries:
    max_infection_rates.append(corona_dataset_aggregated.loc[c].diff().max())
corona_dataset_aggregated["Total COVID 19 Cases"] = max_infection_rates
corona_dataset_aggregated.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# Afghanistan           0        0        0        0        0        0        0
# Albania               0        0        0        0        0        0        0
# Algeria               0        0        0        0        0        0        0
# Andorra               0        0        0        0        0        0        0
# Angola                0        0        0        0        0        0        0
#
#                 1/29/20  1/30/20  1/31/20  ...  4/22/20  4/23/20  4/24/20  \
# Country/Region                             ...
# Afghanistan           0        0        0  ...     1176     1279     1351
# Albania               0        0        0  ...      634      663      678
# Algeria               0        0        0  ...     2910     3007     3127
# Andorra               0        0        0  ...      723      723      731
# ...

# %% [markdown]
# #Copying final data to new dataframe

# %%
corona_data = pd.DataFrame(corona_dataset_aggregated["Total COVID 19 Cases"])
corona_data.head(15)
# Out:
#                      Total COVID 19 Cases
# Country/Region
# Afghanistan                         232.0
# Albania                              34.0
# Algeria                             199.0
# Andorra                              43.0
# Angola                                5.0
# Antigua and Barbuda                   6.0
# Argentina                           291.0
# Armenia                             134.0
# Australia                           497.0
# Austria                            1321.0
# Azerbaijan                          105.0
# Bahamas                               7.0
# Bahrain                             301.0
# Bangladesh                          641.0
# Barbados                             12.0

# %% [markdown]
# #Analysing data after COVID 19

# %%
happiness_report_csv = pd.read_csv("worldwide_happiness_report.csv")
happiness_report_csv.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %%
Useless_cols = ["Social support", "Generosity"]
happiness_report_csv.drop(Useless_cols,axis = 1, inplace = True)

# %%
happiness_report_csv.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  \
# 0             1           Finland  7.769           1.340
# 1             2           Denmark  7.600           1.383
# 2             3            Norway  7.554           1.488
# 3             4           Iceland  7.494           1.380
# 4             5       Netherlands  7.488           1.396
#
#    Healthy life expectancy  Freedom to make life choices  \
# 0                    0.986                         0.596
# 1                    0.996                         0.592
# 2                    1.028                         0.603
# 3                    1.026                         0.591
# 4                    0.999                         0.557
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# 2                      0.341
# 3                      0.118
# 4                      0.298

# %%
happiness_report_csv.drop("Overall rank", axis = 1, inplace = True)

# %%
happiness_report_csv.head()
# Out:
#   Country or region  Score  GDP per capita  Healthy life expectancy  \
# 0           Finland  7.769           1.340                    0.986
# 1           Denmark  7.600           1.383                    0.996
# 2            Norway  7.554           1.488                    1.028
# 3           Iceland  7.494           1.380                    1.026
# 4       Netherlands  7.488           1.396                    0.999
#
#    Freedom to make life choices  Perceptions of corruption
# 0                         0.596                      0.393
# 1                         0.592                      0.410
# 2                         0.603                      0.341
# 3                         0.591                      0.118
# 4                         0.557                      0.298

# %%
happiness_report_csv.set_index("Country or region", inplace = True)
happiness_report_csv.head()
# Out:
#                    Score  GDP per capita  Healthy life expectancy  \
# Country or region
# Finland            7.769           1.340                    0.986
# Denmark            7.600           1.383                    0.996
# Norway             7.554           1.488                    1.028
# Iceland            7.494           1.380                    1.026
# Netherlands        7.488           1.396                    0.999
#
#                    Freedom to make life choices  Perceptions of corruption
# Country or region
# Finland                                   0.596                      0.393
# Denmark                                   0.592                      0.410
# Norway                                    0.603                      0.341
# Iceland                                   0.591                      0.118
# Netherlands                               0.557                      0.298

# %% [markdown]
# #Merging Corona Data and Happiness Report

# %%
corona_data.shape
# Out:
# (187, 1)

# %%
happiness_report_csv.shape
# Out:
# (156, 5)

# %%
data= corona_data.join(happiness_report_csv, how="inner")
data.head()
# Out:
#              Total COVID 19 Cases  Score  GDP per capita  \
# Afghanistan                 232.0  3.203           0.350
# Albania                      34.0  4.719           0.947
# Algeria                     199.0  5.211           1.002
# Argentina                   291.0  6.086           1.092
# Armenia                     134.0  4.559           0.850
#
#              Healthy life expectancy  Freedom to make life choices  \
# Afghanistan                    0.361                         0.000
# Albania                        0.874                         0.383
# Algeria                        0.785                         0.086
# Argentina                      0.881                         0.471
# Armenia                        0.815                         0.283
#
#              Perceptions of corruption
# Afghanistan                      0.025
# Albania                          0.027
# Algeria                          0.114
# Argentina                        0.050
# ...

# %%
dataLeft= corona_data.join(happiness_report_csv, how="left")
dataLeft.head()
# Out:
#                 Total COVID 19 Cases Country or region  Score  GDP per capita  \
# Country/Region
# Afghanistan                    232.0               NaN    NaN             NaN
# Albania                         34.0               NaN    NaN             NaN
# Algeria                        199.0               NaN    NaN             NaN
# Andorra                         43.0               NaN    NaN             NaN
# Angola                           5.0               NaN    NaN             NaN
#
#                 Healthy life expectancy  Freedom to make life choices  \
# Country/Region
# Afghanistan                         NaN                           NaN
# Albania                             NaN                           NaN
# Algeria                             NaN                           NaN
# Andorra                             NaN                           NaN
# Angola                              NaN                           NaN
#
#                 Perceptions of corruption
# ...

# %%
data.shape
# Out:
# (143, 6)

# %%
#Checking correlation between all variables

# %%
data.corr()
# Out:
#                               Total COVID 19 Cases     Score  GDP per capita  \
# Total COVID 19 Cases                      1.000000  0.228783        0.250118
# Score                                     0.228783  1.000000        0.793847
# GDP per capita                            0.250118  0.793847        1.000000
# Healthy life expectancy                   0.289263  0.799893        0.863062
# Freedom to make life choices              0.078196  0.587007        0.394603
# Perceptions of corruption                 0.097703  0.420437        0.311577
#
#                               Healthy life expectancy  \
# Total COVID 19 Cases                         0.289263
# Score                                        0.799893
# GDP per capita                               0.863062
# Healthy life expectancy                      1.000000
# Freedom to make life choices                 0.427892
# Perceptions of corruption                    0.314811
#
# ...

# %%
#Visualizating our results

# %%
data.head()
# Out:
#              Total COVID 19 Cases  Score  GDP per capita  \
# Afghanistan                 232.0  3.203           0.350
# Albania                      34.0  4.719           0.947
# Algeria                     199.0  5.211           1.002
# Argentina                   291.0  6.086           1.092
# Armenia                     134.0  4.559           0.850
#
#              Healthy life expectancy  Freedom to make life choices  \
# Afghanistan                    0.361                         0.000
# Albania                        0.874                         0.383
# Algeria                        0.785                         0.086
# Argentina                      0.881                         0.471
# Armenia                        0.815                         0.283
#
#              Perceptions of corruption
# Afghanistan                      0.025
# Albania                          0.027
# Algeria                          0.114
# Argentina                        0.050
# ...

# %%
#Plotting GDP Vs Total Covid 19 cases

# %%
x = data["GDP per capita"]
y = data["Total COVID 19 Cases"]
sns.scatterplot(x,np.log(y))
# Out:
# C:\Users\shiva\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='GDP per capita', ylabel='Total COVID 19 Cases'>

# %%
sns.regplot(x,np.log(y))
# Out:
# C:\Users\shiva\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='GDP per capita', ylabel='Total COVID 19 Cases'>
